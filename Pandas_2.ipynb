# %% [markdown]
# <a href="https://colab.research.google.com/github/rafayel404/Pandas/blob/main/Pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# using lists
student_data = [
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]
df=pd.DataFrame(student_data,columns=['marks','iq','package'])
df
# Out:
#    marks   iq  package
# 0    100   80       10
# 1     90   70        7
# 2    120  100       14
# 3     80   50        2

# %%
# using dicts

student_dict = {
    'name':['rafayel','shium','rana','antu','amit','ankita'],
    'iq':[100,90,120,80,0,0],
    'marks':[80,70,100,50,0,0],
    'package':[10,7,14,2,0,0]
}

students = pd.DataFrame(student_dict)
students.set_index('name',inplace=True)
students
# Out:
#       name   iq  marks  package
# 0  rafayel  100     80       10
# 1    shium   90     70        7
# 2     rana  120    100       14
# 3     antu   80     50        2
# 4     amit    0      0        0
# 5   ankita    0      0        0

# %%
movies=pd.read_csv('/content/movies.csv')
movies.sample(5)
# Out:
#                    title_x    imdb_id  \
# 422    Second Hand Husband  tt3948240
# 1182  Love Ke Chakkar Mein  tt0833493
# 464       Babloo Happy Hai  tt3426144
# 1027     Hello (2008 film)  tt1087856
# 1508    Chor Machaaye Shor  tt0331216
#
#                                             poster_path  \
# 422   https://upload.wikimedia.org/wikipedia/en/thum...
# 1182                                                NaN
# 464   https://upload.wikimedia.org/wikipedia/en/thum...
# 1027  https://upload.wikimedia.org/wikipedia/en/thum...
# 1508  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link               title_y  \
# 422   https://en.wikipedia.org/wiki/Second_Hand_Husband   Second Hand Husband
# 1182  https://en.wikipedia.org/wiki/Love_Ke_Chakkar_...  Love Ke Chakkar Mein
# 464      https://en.wikipedia.org/wiki/Babloo_Happy_Hai      Babloo Happy Hai
# ...

# %%
ipl=pd.read_csv('/content/ipl-matches.csv')
ipl.sample(5)
# Out:
#           ID       City        Date Season  MatchNumber  \
# 11   1304109     Mumbai  2022-05-15   2022           63
# 570   598055       Pune  2013-05-11   2013           58
# 695   548312     Jaipur  2012-04-08   2012            7
# 312  1136563    Kolkata  2018-04-08   2018            3
# 1    1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                            Team1                  Team2  \
# 11              Rajasthan Royals   Lucknow Super Giants
# 570                Pune Warriors         Mumbai Indians
# 695             Rajasthan Royals  Kolkata Knight Riders
# 312  Royal Challengers Bangalore  Kolkata Knight Riders
# 1    Royal Challengers Bangalore       Rajasthan Royals
#
#                                 Venue             TossWinner TossDecision  \
# 11          Brabourne Stadium, Mumbai       Rajasthan Royals          bat
# 570        Subrata Roy Sahara Stadium          Pune Warriors          bat
# ...

# %% [markdown]
# ## DataFrame Attributes and Methods

# %%
# shape
movies.shape
# Out:
# (1629, 18)

# %%
ipl.shape
# Out:
# (950, 20)

# %%
# dtypes
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
# index
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
# columns
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
# values
students.values # this will give me a 2D array
# Out:
# array([['rafayel', 100, 80, 10],
#        ['shium', 90, 70, 7],
#        ['rana', 120, 100, 14],
#        ['antu', 80, 50, 2],
#        ['amit', 0, 0, 0],
#        ['ankita', 0, 0, 0]], dtype=object)

# %%
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
# info()
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# describe()
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
# isnull
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
# duplicated() this tell me wheather any row is duplicate or not
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
# rename - do not change permanently
students
# Out:
#       name   iq  marks  package
# 0  rafayel  100     80       10
# 1    shium   90     70        7
# 2     rana  120    100       14
# 3     antu   80     50        2
# 4     amit    0      0        0
# 5   ankita    0      0        0

# %%
students.rename(columns={'marks':'percentage','package':'lpa'})
# Out:
#       name   iq  percentage  lpa
# 0  rafayel  100          80   10
# 1    shium   90          70    7
# 2     rana  120         100   14
# 3     antu   80          50    2
# 4     amit    0           0    0
# 5   ankita    0           0    0

# %% [markdown]
# ## Mathematical Methods

# %%
# sum()
students['marks'].sum()
# Out:
# np.int64(300)

# %%
students.sum() # thsi will concatinate strings of column
# Out:
# name       rafayelshiumranaantuamitankita
# iq                                    390
# marks                                 300
# package                                33
# dtype: object

# %%
# row wise
# sum(axis=1)
# mean(axis=1)
# var(axis=1) ... etc

# %% [markdown]
# ## Selecting cols from a DataFrame

# %%
movies[['title_x','imdb_rating']]
# Out:
#                                    title_x  imdb_rating
# 0                 Uri: The Surgical Strike          8.4
# 1                            Battalion 609          4.1
# 2     The Accidental Prime Minister (film)          6.1
# 3                          Why Cheat India          6.0
# 4                          Evening Shadows          7.3
# ...                                    ...          ...
# 1624                 Tera Mera Saath Rahen          4.9
# 1625                  Yeh Zindagi Ka Safar          3.0
# 1626                       Sabse Bada Sukh          6.1
# 1627                                 Daaka          7.4
# 1628                              Humsafar          9.0
#
# [1629 rows x 2 columns]

# %%
ipl[['Team1','Team2','WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %% [markdown]
# ### Selecting rows from a DataFrame
#
# - **iloc** - searches using index positions
# - **loc** - searches using index labels

# %%
# single row
movies.iloc[5]
# Out:
# title_x                                                   Soni (film)
# imdb_id                                                     tt6078866
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link                   https://en.wikipedia.org/wiki/Soni_(film)
# title_y                                                          Soni
# original_title                                                   Soni
# is_adult                                                            0
# year_of_release                                                  2018
# runtime                                                            97
# genres                                                          Drama
# imdb_rating                                                       7.2
# imdb_votes                                                       1595
# story               Soni  a young policewoman in Delhi  and her su...
# ...

# %%
# multiple row
movies.iloc[2:6]
# Out:
#                                 title_x    imdb_id  \
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866
#
#                                          poster_path  \
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                          title_y                 original_title  is_adult  \
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
# ...

# %%
ipl.iloc[1:6:2]
# Out:
#         ID       City        Date Season  MatchNumber  \
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 5  1304115     Mumbai  2022-05-21   2022           69
#
#                          Team1             Team2  \
# 1  Royal Challengers Bangalore  Rajasthan Royals
# 3             Rajasthan Royals    Gujarat Titans
# 5               Delhi Capitals    Mumbai Indians
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
# 3             Eden Gardens, Kolkata    Gujarat Titans        field         N
# 5          Wankhede Stadium, Mumbai    Mumbai Indians        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
# 3    Gujarat Titans  Wickets     7.0    NaN       DA Miller
# ...

# %%
# fancy indexing
movies.iloc[[0,4,5]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
# loc --> it works on leveled index also

students
students.loc['rafayel'] # this will give me series. Single row is also a series
# Out:
# iq         100
# marks       80
# package     10
# Name: rafayel, dtype: int64

# %%
students.loc[['rafayel','shium','antu']]
# Out:
#           iq  marks  package
# name
# rafayel  100     80       10
# shium     90     70        7
# antu      80     50        2

# %%
students.iloc[[0,3,4]]
# Out:
#           iq  marks  package
# name
# rafayel  100     80       10
# antu      80     50        2
# amit       0      0        0

# %% [markdown]
# ## Selecting both rows and cols

# %%
movies.iloc[0:3,0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:2,'title_x':'poster_path'] # when i use iloc i need to give position of index where loc needs label name
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# ## Filtering a Dataframe

# %%
ipl.sample(5)
# Out:
#           ID       City        Date   Season MatchNumber             Team1  \
# 818   419122     Mumbai  2010-03-22  2009/10          17    Mumbai Indians
# 141  1216506  Abu Dhabi  2020-11-01  2020/21          53   Kings XI Punjab
# 724   501249     Jaipur  2011-05-09     2011          52  Rajasthan Royals
# 110  1254081      Delhi  2021-04-29     2021          24  Rajasthan Royals
# 235  1178394  Hyderabad  2019-04-06     2019          19    Mumbai Indians
#
#                      Team2                               Venue  \
# 818  Kolkata Knight Riders                   Brabourne Stadium
# 141    Chennai Super Kings                Sheikh Zayed Stadium
# 724    Chennai Super Kings              Sawai Mansingh Stadium
# 110         Mumbai Indians         Arun Jaitley Stadium, Delhi
# 235    Sunrisers Hyderabad  Rajiv Gandhi International Stadium
#
#                 TossWinner TossDecision SuperOver          WinningTeam  \
# ...

# %%
# find all the final winners

ipl[ipl['MatchNumber']=='Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# how many super over finishes have occured
ipl[ipl['SuperOver']=="Y"].shape[0]
# Out:
# 14

# %%
# how many matches has csk won in kolkata
y=ipl[ipl['WinningTeam']=='Chennai Super Kings']
y[y['City']=='Kolkata'].shape[0]

ipl[(ipl['WinningTeam']=='Chennai Super Kings') & (ipl['City']=='Kolkata')].shape[0]
# Out:
# 5

# %%
# toss winner is match winner in percentage
ipl[ipl['TossWinner']==ipl['WinningTeam']].shape[0]/ipl.shape[0] *100
# Out:
# 51.473684210526315

# %%
# movies with rating higher than 8 and votes>10000
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
# Action movies with rating higher than 7.5
#filter1=movies['genres'].str.split('|').apply(lambda x: 'Action' in x)
filter1=movies['genres'].str.contains('Action')
filter2= movies['imdb_rating'] > 7.5
movies[filter1 & filter2]
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %% [markdown]
# ### Adding new cols

# %%
# completely new
movies['Country'] = 'India'
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
# from existing ones
m=movies.dropna().copy()

# %%
m.shape
# Out:
# (298, 19)

# %%
m['Lead']=m['actors'].str.split('|').apply(lambda x:x[0]) # added the first name of lead actor
m.head(2)
# Out:
#           title_x    imdb_id  \
# 11      Gully Boy  tt2395469
# 34  Yeh Hai India  tt5525846
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                       wiki_link        title_y original_title  \
# 11      https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy      Gully Boy
# 34  https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India  Yeh Hai India
#
#     is_adult  year_of_release runtime                  genres  imdb_rating  \
# 11         0             2019     153             Drama|Music          8.2
# 34         0             2017     128  Action|Adventure|Drama          5.7
#
#     imdb_votes                                              story  \
# 11       22440  Gully Boy is a film about a 22-year-old boy "M...
# 34         169  Yeh Hai India  follows the story of a 25 years...
#
# ...

# %%
# astype
ipl['ID'] = ipl['ID'].astype('int32')

# %%
# ipl['Season'] = ipl['Season'].astype('category')
ipl['Team1'] = ipl['Team1'].astype('category')
ipl['Team2'] = ipl['Team2'].astype('category')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...
